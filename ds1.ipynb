# %%
import pandas as pd
from IPython.display import display
file=pd.read_csv('moviesdatabase.txt',sep="\,",names=['Movie_ID','Movie_name','Year_of_release','Rating_of_the_movie','Movie_duration_in_seconds'])
display(file)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#        Movie_ID                                         Movie_name  \
# 0             1                     The Nightmare Before Christmas
# 1             2                                          The Mummy
# 2             3                               Orphans of the Storm
# 3             4                               The Object of Beauty
# 4             5                                         Night Tide
# ...         ...                                                ...
# 49585     49586                                  Winter Wonderland
# ...

# %%
total_rows=len(file)
display('Total number of movies')
display(total_rows+1)
# Out:
# 'Total number of movies'
# 49591

# %%
rating=file[file['Rating_of_the_movie']>4]
display(rating)
# Out:
#        Movie_ID                                         Movie_name  \
# 138         139                                       Pulp Fiction
# 287         288                                  Life Is Beautiful
# 302         303                             Mulan: Special Edition
# 464         465                                       Forrest Gump
# 490         491                                         Braveheart
# ...         ...                                                ...
# 49548     49549                           Life With Boys: Season 1
# 49553     49554                                          Max Steel
# 49555     49556                       Lilyhammer: Season 1 (Recap)
# 49570     49571                           The Short Game (Trailer)
# 49578     49579  Transformers Prime Beast Hunters: Predacons Ri...
#
#        Year_of_release  Rating_of_the_movie  Movie_duration_in_seconds
# 138               1994                  4.1                     9265.0
# ...

# %%
release=file[(file['Year_of_release']>1950) & (file['Year_of_release']<1960)]
display(release)
# Out:
#        Movie_ID                                         Movie_name  \
# 93           94                              House on Haunted Hill
# 97           98                     Godzilla: King of the Monsters
# 99          100                                          High Noon
# 315         316                           Beneath the 12-Mile Reef
# 401         402                    Love Is a Many-Splendored Thing
# ...         ...                                                ...
# 35627     35628  Alfred Hitchcock Presents: Season 3: The Canar...
# 35634     35635  Alfred Hitchcock Presents: Season 3: Impromptu...
# 44640     44641                              Isn't Life Wonderful!
# 44722     44723  Disney Animation Collection: Vol. 4: The Torto...
# 44766     44767  Disney Animation Collection: Vol. 2: Three Lit...
#
#        Year_of_release  Rating_of_the_movie  Movie_duration_in_seconds
# 93                1959                  3.6                     4491.0
# ...

# %%
rating=file[(file['Rating_of_the_movie']>3) & (file['Rating_of_the_movie']<4)]
display(rating)
# Out:
#        Movie_ID                                        Movie_name  \
# 0             1                    The Nightmare Before Christmas
# 1             2                                         The Mummy
# 2             3                              Orphans of the Storm
# 5             6                               One Magic Christmas
# 6             7                                  Muriel's Wedding
# ...         ...                                               ...
# 49575     49576                       Dave Foley: Relatively Well
# 49579     49580             Underground: The Julian Assange Story
# 49580     49581           Curious George: A Very Monkey Christmas
# 49582     49583  Lady Gaga &#38; The Muppets' Holiday Spectacular
# 49584     49585                                      Silver Bells
#
#        Year_of_release  Rating_of_the_movie  Movie_duration_in_seconds
# 0                 1993                  3.9                     4568.0
# ...

# %%
timing=file[file['Movie_duration_in_seconds']>7200]
display(timing)
# Out:
#        Movie_ID                                         Movie_name  \
# 2             3                               Orphans of the Storm
# 12           13                              The Birth of a Nation
# 13           14                               The Boys from Brazil
# 20           21                         Born on the Fourth of July
# 21           22                                     Broadcast News
# ...         ...                                                ...
# 45107     45108                                             Settai
# 46831     46832  WWE for All Mankind: The Life &#38; Career of ...
# 46948     46949                     Example Short XII 23976 2 Hour
# 48713     48714     WWE: The Top 25 Rivalries in Wrestling History
# 49054     49055                       Theeya Velai Seyyanum Kumaru
#
#        Year_of_release  Rating_of_the_movie  Movie_duration_in_seconds
# 2                 1921                  3.2                     9062.0
# ...

# %%
eachyear=file.groupby(['Year_of_release']).count()
print(eachyear)
# Out:
#                  Movie_ID  Movie_name  Rating_of_the_movie  \
# Year_of_release
# 1913                    3           3                    3
# 1914                   20          20                    5
# 1915                    1           1                    1
# 1916                    1           1                    1
# 1918                    1           1                    1
# ...                   ...         ...                  ...
# 2010                 5107        5107                 1102
# 2011                 5511        5511                 1346
# 2012                 4339        4339                 1130
# 2013                  981         981                  345
# 2014                    1           1                    1
#
#                  Movie_duration_in_seconds
# Year_of_release
# 1913                                     3
# 1914                                    18
# 1915                                     1
# 1916                                     1
# ...
